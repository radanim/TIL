# %% [markdown]
# <a href="https://colab.research.google.com/github/radanim/TIL/blob/master/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%84%EC%B2%98%EB%A6%AC_%EB%B0%8F_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
exchange_list=[["USD","USA","1359.5","WON"],
              ["JPN","JAPAN","974.4","WON"],
              ["CNY","CHINA","195.0","WON"]]

# %%
pd.DataFrame(exchange_list)
# Out:
#      0      1       2    3
# 0  USD    USA  1359.5  WON
# 1  JPN  JAPAN   974.4  WON
# 2  CNY  CHINA   195.0  WON

# %%
pd.DataFrame(exchange_list,columns=["Exchange","National","Price","Unit"])
# Out:
#   Exchange National   Price Unit
# 0      USD      USA  1359.5  WON
# 1      JPN    JAPAN   974.4  WON
# 2      CNY    CHINA   195.0  WON

# %%
pd.read_csv("C:/Users/user/Downloads/AI 인력양성교육/1SBO_Zr/ST-SBO.D31.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-653099330436> in <module>
# ----> 1 pd.read_csv("C:/Users/user/Downloads/AI 인력양성교육/1SBO_Zr/ST-SBO.D31.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-93f6f21b-f630-4d8e-88ce-6c24f6aae92e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93f6f21b-f630-4d8e-88ce-6c24f6aae92e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ST-SBO.D31.CSV to ST-SBO.D31.CSV

# %%
import io
import pandas as pd

# %%
data = pd.read_csv(io.BytesIO(myfile['ST-SBO.D31.CSV']))
data.head()
# Out:
#                     TIME                MCR             MH2CR  \
# 0                SECONDS                 KG                KG
# 1       .000000000000000  136571.2556456919  .000000000000000
# 2  .1000000000000000E-02  136571.2556456919  .000000000000000
# 3      3.616650440082814  136571.2556456919  .000000000000000
# 4      7.016650440082817  136571.2556456919  .000000000000000
#
#                MWCRN            MH2CR1               QWCR               TWCR  \
# 0                 KG                KG                  W                  K
# 1  14274.55651076452  .000000000000000  3569134332.242902  582.2588850182683
# 2  14274.63191148562  .000000000000000  3562070406.212115  582.2588850182684
# 3  14278.09566928881  .000000000000000  2982706488.962348  581.9486723296764
# 4  14395.66942938748  .000000000000000  1863352512.809901  579.4086636008362
#
#                  ZWV            WGUPCR            MH2CBT  ...  \
# 0                  M              KG/S                KG  ...
# ...

# %%
filename = "C:/Users/user/Downloads/AI 인력양성교육/1SBO_Zr/ST-SBO.D31.csv"

# %%
data = pd.read_csv(filename)
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-210a143c0aee> in <module>
# ----> 1 data = pd.read_csv(filename)
#       2 data.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
